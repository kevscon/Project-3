# %% [markdown]
# # County Election EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in data file

df = pd.read_csv('county_election_data_2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  code      Name State  population  land_area  growth  \
# 0           0  1001  Autauga     AL     55504.0     594.44     1.7
# 1           1  1003  Baldwin     AL    212628.0    1589.78    16.7
# 2           2  1005  Barbour     AL     25270.0     884.88    -8.0
# 3           3  1007     Bibb     AL     22668.0     622.58    -1.1
# 4           4  1009   Blount     AL     58013.0     644.78     1.2
#
#    households  median_age  hisp_pop       ...        college_rate  votes_dem  \
# 0     20800.0        37.8    1416.0       ...                24.6     5908.0
# 1     75149.0        42.3    8712.0       ...                29.5    18409.0
# 2      9122.0        38.7    1147.0       ...                12.9     4848.0
# 3      7048.0        40.2     502.0       ...                12.0     1874.0
# 4     20619.0        40.8    5036.0       ...                13.0     2150.0
#
#    votes_gop  total_votes   per_dem   per_gop     diff  per_point_diff  \
# 0    18110.0      24661.0  0.239569  0.734358  12202.0           49.48
# 1    72780.0      94090.0  0.195653  0.773515  54371.0           57.79
# 2     5431.0      10390.0  0.466603  0.522714    583.0            5.61
# 3     6733.0       8748.0  0.214220  0.769662   4859.0           55.54
# 4    22808.0      25384.0  0.084699  0.898519  20658.0           81.38
#
#    state_abbr     county_name
# 0          AL  Autauga County
# 1          AL  Baldwin County
# 2          AL  Barbour County
# 3          AL     Bibb County
# 4          AL   Blount County
#
# [5 rows x 27 columns]

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# scatter plot point diff by county code
plt.scatter(df['code'], df['per_point_diff'])
figsize=(8,6)

# %%
st_dist = pd.DataFrame(df.groupby(['State'])['per_point_diff'].mean())

# %%
st_dist.reset_index(inplace=True)

# %%
# plot state vs point diff
objects = st_dist['State']
y_pos = np.arange(len(objects))
 
plt.bar(st_dist['State'], st_dist['per_point_diff'])
plt.xticks(y_pos, objects)
plt.ylabel('Per Point Diff')
plt.xlabel('State')
 
plt.show()
figsize=(12, 12)

# %%
# sort data by smallest point dif values

df.sort_values(['per_point_diff'])
# Out:
#        code                              Name State  population  land_area  \
# 2783  49019                            Grand     UT      9674.0    3671.54
# 2958  53011                            Clark     WA    474643.0     629.00
# 1705  31109                        Lancaster     NE    314358.0     837.55
# 587   16081                            Teton     ID     11381.0     449.46
# 1766  33011                     Hillsborough     NH    409697.0     876.14
# 2812  50019                          Orleans     VT     26841.0     693.27
# 763   18141                        St Joseph     IN    270434.0     457.85
# 1950  37127                             Nash     NC     93991.0     540.41
# 1186  23027                            Waldo     ME     39832.0     729.92
# 2086  39093                           Lorain     OH    307924.0     491.10
# 3103  55111                             Sauk     WI     63981.0     830.90
# 292    8101                           Pueblo     CO    166475.0    2386.10
# 3076  55059                          Kenosha     WI    168521.0     271.99
# 2285  42089                           Monroe     PA    168046.0     608.29
# 1778  34015                       Gloucester     NJ    292206.0     322.01
# 835   19101                        Jefferson     IA     18422.0     435.51
# 1450  28107                           Panola     MS     33994.0     685.14
# 2642  48245                        Jefferson     TX    256299.0     876.30
# 2990  53075                          Whitman     WA     49046.0    2159.09
# 1945  37117                           Martin     NC     22789.0     461.22
# 2086          ...                   23.5    64958.0    65346.0     136654.0
# 3103          ...                   22.3    14692.0    14791.0      31238.0
# 292           ...                   21.2    27945.0    27746.0      60112.0
# 3076          ...                   24.6    35770.0    36025.0      75825.0
# 2285          ...                   23.6    31930.0    31706.0      65944.0
# 1778          ...                   29.9    66355.0    66949.0     138388.0
# 835           ...                   33.1     3702.0     3738.0       8001.0
# 1450          ...                   15.6     7300.0     7371.0      14854.0
# 2642          ...                   18.8    42404.0    42828.0      87363.0
# 2990          ...                   49.8     5521.0     5462.0      12128.0
# 1945          ...                   15.8     5814.0     5874.0      11852.0
# 2249          ...                   38.3   165861.0   163873.0     342572.0
# 533           ...                   12.3     4187.0     4138.0       8422.0
# 233           ...                   16.5    73939.0    72960.0     156141.0
# 1190          ...                   39.4   116074.0   114509.0     242939.0
# 2309          ...                   31.8    37582.0    38141.0      79691.0
# 1453          ...                   15.7     7636.0     7748.0      15633.0
# 1364          ...                   42.0    36266.0    35668.0      79277.0
# 880           ...                   27.6     5238.0     5332.0      11217.0
# 2624          ...                   36.3    33117.0    33730.0      71524.0
# 1287          ...                   18.0    36640.0    35962.0      77114.0
# ...           ...                    ...        ...        ...          ...
# 2536          ...                   36.5       31.0      330.0        365.0
# 2789          ...                   20.7       31.0      537.0        617.0
# 2761          ...                   14.1      194.0     2087.0       2306.0
# 2385          ...                   19.9       77.0      936.0       1044.0
# 2670          ...                    3.0        4.0       57.0         64.0
# 2140          ...                   19.8       70.0      962.0       1077.0
# 2675          ...                   16.2       40.0      454.0        497.0
# 2525          ...                   23.1       70.0      924.0       1017.0
# 1653          ...                   26.8       16.0      237.0        263.0
# 2728          ...                   25.2      103.0     1378.0       1502.0
# 1709          ...                   24.5       14.0      257.0        286.0
# 2389          ...                   29.7       38.0      694.0        769.0
# 983           ...                   24.9       45.0      711.0        779.0
# 2692          ...                   17.4       40.0      571.0        620.0
# 2606          ...                   25.2       34.0      553.0        602.0
# 1654          ...                   17.0       18.0      355.0        390.0
# 1693          ...                   20.6       30.0      471.0        510.0
# 1610          ...                   14.6       34.0      653.0        715.0
# 1688          ...                   22.0       20.0      367.0        394.0
# 316           ...                   55.4   260223.0    11553.0     280272.0
# 2654          ...                   23.2        5.0      149.0        159.0
# 2716          ...                   31.5       20.0      524.0        550.0
# 85            ...                    NaN        NaN        NaN          NaN
# 87            ...                    NaN        NaN        NaN          NaN
# 91            ...                    NaN        NaN        NaN          NaN
# 329           ...                    NaN        NaN        NaN          NaN
# 1650          ...                    NaN        NaN        NaN          NaN
# 2913          ...                    NaN        NaN        NaN          NaN
# 2918          ...                    NaN        NaN        NaN          NaN
# 2946          ...                    NaN        NaN        NaN          NaN
#
#        per_dem   per_gop      diff  per_point_diff  state_abbr  \
# 2783  0.433573  0.434022       2.0            0.04          UT
# 2958  0.463250  0.462704     107.0            0.05          WA
# 1705  0.466345  0.465752      77.0            0.06          NE
# 587   0.434354  0.435159       4.0            0.08          ID
# 1766  0.472833  0.474846     424.0            0.20          NH
# 763      St. Joseph County
# 1950           Nash County
# 1186          Waldo County
# 2086         Lorain County
# 3103           Sauk County
# 292          Pueblo County
# 3076        Kenosha County
# 2285         Monroe County
# 1778     Gloucester County
# 835       Jefferson County
# 1450         Panola County
# 2642      Jefferson County
# 2990        Whitman County
# 1945         Martin County
# 2249          Bucks County
# 533      Washington County
# 233      Stanislaus County
# 1190   Anne Arundel County
# 2309           Kent County
# 1453           Pike County
# 1364        Olmsted County
# 880      Winneshiek County
# 2624           Hays County
# 1287       Muskegon County
# ...                    ...
# 2536         Borden County
# 2789          Piute County
# 2761        Wheeler County
# 2385         Haakon County
# 2670         Loving County
# 2140       Cimarron County
# 2675       McMullen County
# 2525      Armstrong County
# 1653         Arthur County
# 2728    Shackelford County
# 1709      McPherson County
# 2389        Harding County
# 983         Wallace County
# 2692         Motley County
# 2606      Glasscock County
# 1654         Banner County
# 1693          Hayes County
# 1610       Garfield County
# 1688          Grant County
# 316   District of Columbia
# 2654           King County
# 2716        Roberts County
# 85                     NaN
# 87                     NaN
# 91                     NaN
# 329                    NaN
# 1650                   NaN
# 2913                   NaN
# 2918                   NaN
# 2946                   NaN
#
# [3142 rows x 26 columns]

# %%
# close counties

#num_counties = int(0.1 * len(df))
df_1 = df[df['per_point_diff'] <= 3]
len(df_1)
# Out:
# 94

# %%
df['per_point_diff'].hist(bins=20)

# %% [markdown]
# ## Feature Engineering

# %%
# create density column

df['density'] = df['population'] / df['land_area']

# %%
# create white population rate

df['white_rate'] = df['white_pop'] / df['population']

# %%
# create hispanic population rate

df['hisp_rate'] = df['hisp_pop'] / df['population']

# %%
df.head()
# Out:
#    code      Name State  population  land_area  growth  households  \
# 0  1001  Autauga     AL     55504.0     594.44     1.7     20800.0
# 1  1003  Baldwin     AL    212628.0    1589.78    16.7     75149.0
# 2  1005  Barbour     AL     25270.0     884.88    -8.0      9122.0
# 3  1007     Bibb     AL     22668.0     622.58    -1.1      7048.0
# 4  1009   Blount     AL     58013.0     644.78     1.2     20619.0
#
#    median_age  hisp_pop  white_pop    ...      total_votes   per_dem  \
# 0        37.8    1416.0    42311.0    ...          24661.0  0.239569
# 1        42.3    8712.0   172441.0    ...          94090.0  0.195653
# 2        38.7    1147.0    12430.0    ...          10390.0  0.466603
# 3        40.2     502.0    17370.0    ...           8748.0  0.214220
# 4        40.8    5036.0    55073.0    ...          25384.0  0.084699
#
#     per_gop     diff  per_point_diff  state_abbr     county_name     density  \
# 0  0.734358  12202.0           49.48          AL  Autauga County   93.371913
# 1  0.773515  54371.0           57.79          AL  Baldwin County  133.746808
# 2  0.522714    583.0            5.61          AL  Barbour County   28.557545
# 3  0.769662   4859.0           55.54          AL     Bibb County   36.409779
# 4  0.898519  20658.0           81.38          AL   Blount County   89.973324
#
#    white_rate  hisp_rate
# 0    0.762305   0.025512
# 1    0.810999   0.040973
# 2    0.491888   0.045390
# 3    0.766278   0.022146
# 4    0.949322   0.086808
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Remove unneeded columns

# %%
df.columns
# Out:
# Index(['code', 'Name', 'State', 'population', 'land_area', 'growth',
#        'households', 'median_age', 'hisp_pop', 'white_pop', 'per_cap_income',
#        'hh_income', 'labor_force', 'unempl_rate', 'poverty_rate', 'hs_rate',
#        'college_rate', 'votes_dem', 'votes_gop', 'total_votes', 'per_dem',
#        'per_gop', 'diff', 'per_point_diff', 'state_abbr', 'county_name',
#        'density', 'white_rate', 'hisp_rate'],
#       dtype='object')

# %%
columns = ['code', 'Name', 'State', 'hisp_pop', 'white_pop', 'labor_force',
           'votes_dem', 'votes_gop', 'total_votes', 'per_dem', 'land_area',
           'per_gop', 'diff', 'state_abbr', 'county_name']
df_model = df.drop(columns, axis=1)

# %% [markdown]
# df_model = df.drop(df.columns[[0, 1, 2, 14, 15, 16, 17, 18, 19, 20, 21, 22]], axis=1)

# %%
df_model.head()
# Out:
#    population  growth  households  median_age  per_cap_income  hh_income  \
# 0     55504.0     1.7     20800.0        37.8         39721.0    54487.0
# 1    212628.0    16.7     75149.0        42.3         41286.0    56460.0
# 2     25270.0    -8.0      9122.0        38.7         31788.0    32884.0
# 3     22668.0    -1.1      7048.0        40.2         29264.0    43079.0
# 4     58013.0     1.2     20619.0        40.8         31470.0    47213.0
#
#    unempl_rate  poverty_rate  hs_rate  college_rate  per_point_diff  \
# 0          3.9          13.5     87.6          24.6           49.48
# 1          4.0          11.7     90.0          29.5           57.79
# 2          5.9          29.9     73.8          12.9            5.61
# 3          4.4          20.1     80.7          12.0           55.54
# 4          4.0          14.1     80.0          13.0           81.38
#
#       density  white_rate  hisp_rate
# 0   93.371913    0.762305   0.025512
# 1  133.746808    0.810999   0.040973
# 2   28.557545    0.491888   0.045390
# 3   36.409779    0.766278   0.022146
# 4   89.973324    0.949322   0.086808

# %%
# classify close as '1' and not close as '0'

thresh = 3 # define close election threshold
df_model['close_elect'] = pd.DataFrame(np.where(df['per_point_diff'] <= thresh, 1, 0))

# %%
df_model.head()
# Out:
#    population  growth  households  median_age  per_cap_income  hh_income  \
# 0     55504.0     1.7     20800.0        37.8         39721.0    54487.0
# 1    212628.0    16.7     75149.0        42.3         41286.0    56460.0
# 2     25270.0    -8.0      9122.0        38.7         31788.0    32884.0
# 3     22668.0    -1.1      7048.0        40.2         29264.0    43079.0
# 4     58013.0     1.2     20619.0        40.8         31470.0    47213.0
#
#    unempl_rate  poverty_rate  hs_rate  college_rate  per_point_diff  \
# 0          3.9          13.5     87.6          24.6           49.48
# 1          4.0          11.7     90.0          29.5           57.79
# 2          5.9          29.9     73.8          12.9            5.61
# 3          4.4          20.1     80.7          12.0           55.54
# 4          4.0          14.1     80.0          13.0           81.38
#
#       density  white_rate  hisp_rate  close_elect
# 0   93.371913    0.762305   0.025512            0
# 1  133.746808    0.810999   0.040973            0
# 2   28.557545    0.491888   0.045390            0
# 3   36.409779    0.766278   0.022146            0
# 4   89.973324    0.949322   0.086808            0

# %%
sns.pairplot(df_model.dropna(how='any'))

# %%
df_model.to_pickle('dataframe_2.pkl')
